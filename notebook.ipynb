# %%
from IPython.display import display, HTML
display(HTML(
"""
<a target="_blank" href="https://colab.research.google.com/github/Marchisceddu/finestSAM/notebook.ipynb">
  <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
</a>
"""
))

# %%
# If you use colab
# %pip install Lightning
# %pip install segmentation_models_pytorch
# %pip install wget

# !git clone -b training_print https://github.com/Marchisceddu/finestSAM.git

# %cd finestSAM

# %%
# Download save
import wget
wget.download("https://dl.fbaipublicfiles.com/segment_anything/sam_vit_b_01ec64.pth", "finestSAM/sav")

# %%
# %run finestSAM/__main__.py --mode predict --input "../test/7/0.png"

# %%
# %run finestSAM/__main__.py --mode train
